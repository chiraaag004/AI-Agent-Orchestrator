# %%
import sys
import os
import warnings

# Suppress deprecation warnings for a cleaner output
warnings.filterwarnings("ignore", category=DeprecationWarning)

# This ensures that the script can find the other modules in the project
# when run from the root 'ai_hackathon' directory.
sys.path.insert(0, os.path.abspath(os.getcwd()))

try:
    from agents.atca.graph import travel_graph
    print("✅ travel_graph imported successfully.")
except ImportError as e:
    print(f"❌ Error importing travel_graph: {e}")
    print("Please make sure you are running this notebook from the root of the 'ai_hackathon' project directory.")
# Out:
# ✅ travel_graph imported successfully.

# %%
from IPython.display import Image, display
display(Image(travel_graph.get_graph().draw_mermaid_png()))
